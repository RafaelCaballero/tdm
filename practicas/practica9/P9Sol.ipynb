# %% [markdown]
# # Práctica 7 - Regresión lineal - Solución
#
# ## Tratamiento de datos masivos - Rafael Caballero
#
#
#
# ### Introducción
# Vamos a partir del fichero con las calificaciones de las pruebas PISA a estudiantes por país para intentar establecer **regresiones lineales**, es decir ser capaces de predecir un datos como combinación lineal de otros.
#
# Las columnas de este conjunto son:
#
# ```
# RPC,PAIS,MAT,MAT_FE,MAT_MA,REA,REA_FE,REA_MA,SCI,SCI_FE,SCI_MA
# ```
#
# RCP: Renta per cápita del país.
# PAIS: Nombre del país.
# MAT: Nota del país en matemáticas
# MAT_FE: Nota del país en matemáticas para chicas
# MAT_MA: Nota del país en matemáticas para chicos.
#
# El resto son iguales pero lectura (REA) y ciencias (SCI). La pregunta que nos hacemos es ¿Podemos deducir por ejemplo, la nota en matemáticas de un país a partir de su nota en ciencia y lectura?
#
#
# ### Esquema general
#
#
# Antes de empezar recordemos el esquema general del tratamiento de datos en aprendizaje automática:
#
#
# 0.- Cargar y preparar los datos
#
# 1.- Preparar el regresor/clasificador.
#
# 2.- Aplicarlo con *fit* al conjunto de entrenamiento, lo que genera un modelo.
#
# 3.- Aplicar el modelo al conjunto que queramos con *transform*. Esto sirve tanto para predecir el resultado de nuevos valores como para evaluar el modleo obtenido en el paso 2.

# %% [markdown]
# ### setup

# %%
# %matplotlib inline
import os
# cambiamos las variables del sistema
spark = 'C:\\hlocal\\tdm\\spark\\hadoop\\spark-2.3.2-bin-hadoop2.7'
# en el path se añade
path = os.environ.get('PATH') 
path = path+ ';'+spark+'\\bin;'
os.environ['PATH'] = path
os.environ['SPARK_HOME']= spark 
os.environ['HADOOP_HOME']= spark 
os.environ['PYSPARK_DRIVER_PYTHON']= 'jupyter'
os.environ['PYSPARK_DRIVER_PYTHON_OPTS']='notebook'

# si da problema con collect quizás haya que poner java_home
#os.environ['JAVA_HOME']= 'C:\\Program Files\\Java\\jdk1.8.0_151'
labs = 'C:\\JDK\\jdk8-64bits'
os.environ['JAVA_HOME']= labs
os.environ['PATH'] = os.environ.get('JAVA_HOME')+'\\bin;'+path


import findspark
findspark.init()

import pyspark # only run after findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
sc = spark.sparkContext
print("Preparado!!")
# Out:
# Preparado!!

# %% [markdown]
# ### 0.- Lectura y preprocesado
#
# 1.- Para empezar leemos el fichero como un dataframe, recordando que es un fichero .csv con cabecera y que Spark debe inferir automáticamente el esquema. El dataframe resultado debe llamarse *raw*

# %%
#path = 'c:/hlocal/tdm/PisaRPP.csv'
path = 'c:/hlocal/tdm/PisaRPP.csv'

## Solución
# Load  data
raw = spark.read.format("com.databricks.spark.csv")\
            .options(header='true', inferschema='true') \
            .load(path)


raw.show(5)
# Out:
# +-----+---------+--------+----------------+----------------+--------+----------------+----------------+--------+----------------+----------------+
# |  RPC|     PAIS|     MAT|          MAT_FE|          MAT_MA|     REA|          REA_FE|          REA_MA|     SCI|          SCI_FE|          SCI_MA|
# +-----+---------+--------+----------------+----------------+--------+----------------+----------------+--------+----------------+----------------+
# |13274|  Albania| 413.157|417.750029482799|408.545458736189|405.2588|434.639625546737| 375.75919916958| 427.225|439.442962901842|414.957643727778|
# |15757|  Algeria|359.6062|363.072479076874|356.495105666181|349.8593|366.208166798086|335.185435908668|375.7451|383.220938935314|369.035233788056|
# |21528|Argentina|409.0333|400.443116055612|418.388360865522|425.3031| 432.95807959441|416.966607209736|432.2262|424.994351346692|440.102029698007|
# |52190|Australia|493.8962|490.985500770373|496.761344887127|502.9006|518.865799240277| 487.18552546683|509.9939|508.921647404582|511.049257232073|
# |51936|  Austria|496.7423|483.133026052429|510.098215924204|484.8656|495.075191103096|474.846031609294|495.0375|485.526754333789|504.371197291877|
# +-----+---------+--------+----------------+----------------+--------+----------------+----------------+--------+----------------+----------------+
# only showing top 5 rows

# %%
# para comprobar que está bien podemos ejecutar este código
raw.describe().toPandas().transpose()
# Out:
#              0                   1                   2                 3  \
# summary  count                mean              stddev               min
# RPC         64        37946.421875  23786.070878458875              5998
# PAIS        64                None                None           Albania
# MAT         64  457.90003437499996    51.0110372471199           327.702
# MAT_FE      64   455.5618782766279   49.96876447286404  329.745930838674
# MAT_MA      64  460.28304587737546   52.33950632120393  325.586561113527
# REA         64       459.964196875   48.05284131985104           346.549
# REA_FE      64  474.92981961948334  47.392871168080006  353.277295651411
# REA_MA      64   445.0736252631914  49.836431424287404  335.185435908668
# SCI         64   463.6992656249999   47.34237638410934          331.6388
# SCI_FE      64  463.91620147101105     45.884016452394  330.828991404779
# SCI_MA      64   463.5273017512438  49.393767756932256  332.477014604632
#
#                         4
# summary               max
# RPC                128702
# PAIS              Vietnam
# MAT              564.1897
# MAT_FE   564.254533844227
# MAT_MA    564.12900352855
# REA              535.1002
# REA_FE   550.511163985695
# REA_MA   525.315266235515
# SCI              555.5747
# SCI_FE   552.273030959773
# SCI_MA   558.663734448526

# %% [markdown]
# El siguiente código hace una gráfica de una muestra de los valores (en este caso como son muy pocos, la muestra los tomará todos, pero en general no será así), para hacernos una idea de si se sigue una res

# %%
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


# Función que muesstra una gráfica a partir de una muestra. Parámetros
# datos: el dataframe
# x: el nombre de la columna x
# y: el nombre de la columna y
# puntos: el número de puntoss a mostrar
# color: de los puntos
def grafica(datos,x,y,z, puntos=100, color='darkgreen'):
    
    
    d = datos.select([x,y,z])
    n = datos.count()
    if n<puntos:
        p = 0.99 # seleccionar  casi todos
    else: 
        p = puntos / n
    valores = d.sample(False,p).sort(x).collect()

    # mostrar
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    x_v= list(map(lambda x:x[0],valores))
    y_v=list(map(lambda x:x[1],valores))
    z_v=list(map(lambda x:x[2],valores))
    ax.scatter(x_v,y_v,z_v, color=color)
    plt.xlabel(x) 
    plt.ylabel(y)
    plt.legend()
    plt.show()
   

### Mostramos renta per capita y cada uno de los 3 valores principales
grafica(raw,'SCI', 'REA','MAT', color='blue')
grafica(raw,'REA','MAT','SCI',color='green')
grafica(raw,'MAT','SCI','REA',color='red')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# Antes del siguiente paso, debemos separar las columnas en dos, la que queremos calcular ('MAT') y un vector de features con las otras dos.

# %%
from pyspark.ml.feature import VectorAssembler
# genera un vector a partir de los valores X
assembler = VectorAssembler(
        inputCols=['SCI','REA'],
        outputCol='features')

datosprep =  assembler.transform(raw)
datosprep = datosprep.select(['MAT','features'])

print(datosprep)
# Out:
# DataFrame[MAT: double, features: vector]

# %% [markdown]
# 2.- El siguiente paso es separar el conjunto *datosprep* en dos:  entrenamiento (70%) y prueba (30%). Al dataframe de entrenamiento lo llamaremos *train* y al de prueba *test*.

# %%
# solución 
train,test = datosprep.randomSplit([0.7, 0.3])

# %% [markdown]
# ### 1.- Preparar el regresor
#
# 3.- Ahora nos declaramos una variable con nombre *regresor* de tipo *LinearRegression*. Al crearla nos interesan
# algunos parámetros:
#
# * featuresCol: nombre del vector de features. En nuestro ejemplo como se llama precisamente *features*, no hace falta.
# * labelCol nombre de la columna con la variable depedendiente, en este caso 'MAT'
# * maxIter máximo número de iteraciones, de momento podemos ponerlo a 10
# * regParam parámetro de regularización, para evitar sobreajuste. Podemos poner por ejemplo a 0.1

# %%
from pyspark.ml.regression import LinearRegression
# solucion
regresor = LinearRegression(labelCol = 'MAT', maxIter=10, regParam=0.1)

# %% [markdown]
# ### 2 y 3 .- Aplicar el regresor
#
# 4.- Usar primero *fit* para obtener el modelo (guardarlo en una variable model_rl) sobre el conjunto de entrenamiento

# %%
# Solución
model_rl = regresor.fit(train)

# Print the coefficients and intercept for linear regression
a,b = model_rl.coefficients
c = model_rl.intercept
print(a,b,c)
# Out:
# 0.9442345519573007 0.09536879655697576 -22.941050023436095

# %% [markdown]
# 5.- Aplicar el modelo al conjunto de test mediante el método *transform*, guardando el resultado en una variable *res_test*.

# %%
# Solución
res_test = model_rl.transform(test)

# %%
# para comprobar que está bien podemos ejecutar este código
res_test.show()
# Out:
# +--------+-------------------+------------------+
# |     MAT|           features|        prediction|
# +--------+-------------------+------------------+
# |377.0695|[400.6821,407.3486]|394.24517890854315|
# | 380.259|[408.6691,408.1022]| 401.8586502001114|
# |386.1096|[403.0997,397.2595]| 395.5657750360121|
# | 413.157| [427.225,405.2588]| 419.1086004866458|
# |417.2434|[424.5905,427.2733]|418.72051093131785|
# |441.1899| [445.772,431.7175]| 439.1446530992599|
# |453.6299|[454.8288,467.0395]| 451.0650132214123|
# | 459.816| [456.4836,427.141]|448.82246062856274|
# |482.3051| [490.225,487.7581]|486.46323621774866|
# |485.8432|[492.7861,495.5764]| 489.6271371908879|
# |488.0332|[473.2301,481.5255]| 469.8216688692685|
# |492.3254|  [492.83,487.2501]|488.87451987694647|
# |492.9204|[494.9776,499.3061]| 492.0521242120209|
# |493.8962|[509.9939,502.9006]| 506.5738366538013|
# |495.2233|[513.3035,509.2707]|510.30638409790686|
# |532.4399|[538.3948,515.9585]| 534.6362639490468|
# +--------+-------------------+------------------+

# %% [markdown]
# ### Medida del error
#
# 6.- Para poder medir el error del método, utilizaremos un *RegressionEvaluator*. Crear una variable evalua_rl que se obtenga mediante una llamada a la constructora *RegressionEvaluator(...)*, teniendo en cuenta los siguientes parámetros:
#
# * predictionCol: nombre de la columna que contiene la predicción, que en este caso es "prediction"
#
# * labelCol: columna con el valor real
#
# * metricName: La medida de error, que puede ser "r^2", "mae" o "rmse". En este caso tomar el coeficiente de correlación "r2". Recordemos que cuanto más cercano a 1 mayor será el ajuste.
#
# Para obtener el resultado bastará con llamar al método *evaluate* del evaluador, pasándole como parámetro el dataframe con las predicciones (*res_test*). Mostrar el coeficiente obtenido por pantalla (debe estar alrededor de 0.90)

# %%
from pyspark.ml.evaluation import RegressionEvaluator
#Solucion
evalua_rl = RegressionEvaluator(predictionCol="prediction",labelCol="MAT",metricName="r2")
evalua_rl.evaluate(res_test)
# Out:
# 0.9481944535313223

# %% [markdown]
# 7.- [2 puntos] El fichero *sinmat.csv* contiene datos de REA y SCI para  países (imaginarios) de los que no se pudo hacer la prueba de matemáticas. Queremos predecirla con nuestro modelo.
# Carga el fichero, que quedará en un dataframe almacenado en una variable *sinmat* y predice el resultado de la prueba mat para cada país. El resultado con las predicciones quedará en un dataframe 'conmat'. Por supuesto se puede (y debe) utilizar el modelo del ejercicio 5.

# %%
#pathsm = 'C:/hlocal/tdm/sinmat.csv'
# 7 Solución
pathsm = 'C:/hlocal/tdm/sinmat.csv'
sinmat = spark.read.format("com.databricks.spark.csv")\
            .options(header='true', inferschema='true') \
            .load(pathsm)
presm = assembler.transform(sinmat) # para crear el vector con las features
conmat  = model_rl.transform(presm)
conmat.show()
# Out:
# +-----+-----+-------------+------------------+
# |  REA|  SCI|     features|        prediction|
# +-----+-----+-------------+------------------+
# |327.0|346.0|[346.0,327.0]| 331.0396142824781|
# |327.0|346.1|[346.1,327.0]| 331.1333350152581|
# |327.0|346.2|[346.2,327.0]| 331.2270557480381|
# |327.0|346.3|[346.3,327.0]|331.32077648081804|
# |327.0|346.4|[346.4,327.0]|  331.414497213598|
# |327.0|346.5|[346.5,327.0]|  331.508217946378|
# |327.0|346.6|[346.6,327.0]|  331.601938679158|
# |327.0|346.7|[346.7,327.0]|  331.695659411938|
# |327.0|346.8|[346.8,327.0]|  331.789380144718|
# |327.0|346.9|[346.9,327.0]|331.88310087749795|
# |327.0|347.0|[347.0,327.0]|331.97682161027797|
# |327.0|347.1|[347.1,327.0]|  332.070542343058|
# |327.0|347.2|[347.2,327.0]|332.16426307583794|
# |327.0|347.3|[347.3,327.0]|332.25798380861795|
# |327.0|347.4|[347.4,327.0]| 332.3517045413979|
# |327.0|347.5|[347.5,327.0]|332.44542527417786|
# |327.0|347.6|[347.6,327.0]| 332.5391460069579|
# |327.0|347.7|[347.7,327.0]|332.63286673973784|
# |327.0|347.8|[347.8,327.0]|332.72658747251785|
# |327.0|347.9|[347.9,327.0]| 332.8203082052978|
# +-----+-----+-------------+------------------+
# only showing top 20 rows

# %% [markdown]
# Si se quiere probar el resultado, se puede ejecutar el siguiente bloque, que debe mostrar un plano inclinado:

# %%
grafica(conmat,'prediction', 'REA','SCI', puntos=1000, color='blue')

# %% [markdown]
# 9.- [2 puntos] Queremos ahora intentar predecir la renta per capita (columna RPC) a partir del resto menos PAIS (que es alfanumérica y no puede usarse). Escribir en el siguiente bloque el código para obtener el coeficiente de correlación lineal r^2 a partir del dataframe *raw* obtenido en el ejercicio 1. El código, al final, debe escribir el correspondiente r^2

# %%
# Solución
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import RegressionEvaluator

######## Assembler
columnas_sagradas = ['PAIS','RPC']
input_cols = [name for name in raw.columns if name not in columnas_sagradas]

assembler = VectorAssembler(
        inputCols=[name for name in raw.columns if name not in columnas_sagradas],
        outputCol='features')
### regresor
regresor = LinearRegression(labelCol = 'RPC', maxIter=10, regParam=0.1)

#### la secuencia de etapas a ejecutar para obtener el modelo
pipeline = Pipeline(stages=[assembler, regresor])


splits = raw.randomSplit([0.7, 0.3])
train = splits[0]
test = splits[1]


#### Ojo: pipeline model!!!!
model_rl = pipeline.fit(train)
res_test = model_rl.transform(test)

evalua_rl = RegressionEvaluator(predictionCol="prediction",labelCol="RPC",metricName="r2")
evalua_rl.evaluate(res_test)
# Out:
# 0.07288170547905082

# %%
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import DecisionTreeRegressor
from pyspark.ml.regression import LinearRegression
from pyspark.ml.regression import GBTRegressor
from pyspark.ml.regression import GeneralizedLinearRegression
from pyspark.ml.regression import IsotonicRegression
from pyspark.ml.regression import RandomForestRegressor

featuresCol = 'features'
labelCol = 'RPC'
maxIter = 50
regParam = 0.3
glr = GeneralizedLinearRegression(featuresCol = featuresCol, labelCol = labelCol,maxIter=maxIter, regParam=0.3,family="gaussian", link="identity")
gbt = GBTRegressor(featuresCol = featuresCol, labelCol = labelCol, maxIter=maxIter,\
                              maxDepth=4,lossType="squared"\
                              ) # lossType squared,absolute
lr = LinearRegression(featuresCol = featuresCol, labelCol = labelCol, maxIter=maxIter, regParam=regParam, elasticNetParam=0.8)
dt = DecisionTreeRegressor(featuresCol = featuresCol, labelCol = labelCol)
ir = IsotonicRegression(featuresCol = featuresCol, labelCol = labelCol)
rf = RandomForestRegressor(featuresCol = featuresCol, labelCol = labelCol)

regresores = [glr,gbt,lr,dt,ir,rf]
pipes = [ Pipeline(stages=[assembler, regresor]) for regresor in regresores]

splits = raw.randomSplit([0.7, 0.3])
train = splits[0]
test = splits[1]

# un modelo por cada regresor
models  = [pipeline.fit(train) for pipeline in pipes]

# 
res_tests = [model.transform(test) for model in models]

evalua_rl = RegressionEvaluator(predictionCol="prediction",labelCol="RPC",metricName="mae")
[ evalua_rl.evaluate(res_test) for res_test in res_tests]
# Out:
# [10433.469606737946,
#  37438.99781464059,
#  9286.46848325161,
#  37086.42456140352,
#  9769.59764281651,
#  18248.96668494551]

# %% [markdown]
# ### Validación cruzada
#
# Útil para ajustar hiperparámetros. La 'magia' está en *numfolds*. Por ejemplo un valor de 3 genera una división de 2/3 para training y 1/3 para testing. Esto hace 3 posibles parejas. Para cada parámetros se evaluan todas las parejas y se hace la media, buscando el mejor valor.

# %%
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

# datos para la regresión
raw2 = raw.select(['MAT','SCI','REA']).withColumnRenamed("MAT", "label")

assembler = VectorAssembler(
        inputCols=['SCI','REA'],
        outputCol='features')


### regresor
regresor = LinearRegression()


#### la secuencia de etapas a ejecutar para obtener el modelo
pipeline = Pipeline(stages=[assembler, regresor])


paramGrid = ParamGridBuilder() \
    .addGrid(regresor.maxIter, [5,10, 100, 1000]) \
    .addGrid(regresor.regParam, [0.6,0.4,0.2,0.1, 0.01]) \
    .addGrid(regresor.elasticNetParam, [0.6,0.4,0.2,0.1, 0.01]) \
    .build()
    
crossval = CrossValidator(
                          estimator=pipeline,
                          estimatorParamMaps=paramGrid,
                          evaluator=RegressionEvaluator(metricName="r2"),
                          numFolds=3)  


splits = raw2.randomSplit([0.7, 0.3])
train = splits[0]
test = splits[1]


# Elegir los mejores valores para el modelo
cvModel = crossval.fit(train)


res_test = cvModel.transform(test)

evalua_rl = RegressionEvaluator(metricName="r2")
evalua_rl.evaluate(res_test)
# Out:
# 0.9460098544134194

# %%
bestPipeline = cvModel.bestModel
bestPipeline.stages[1].extractParamMap()
# Out:
# {Param(parent='LinearRegression_4bc192cb341445680f1b', name='aggregationDepth', doc='suggested depth for treeAggregate (>= 2)'): 2,
#  Param(parent='LinearRegression_4bc192cb341445680f1b', name='elasticNetParam', doc='the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty'): 0.01,
#  Param(parent='LinearRegression_4bc192cb341445680f1b', name='epsilon', doc='The shape parameter to control the amount of robustness. Must be > 1.0.'): 1.35,
#  Param(parent='LinearRegression_4bc192cb341445680f1b', name='featuresCol', doc='features column name'): 'features',
#  Param(parent='LinearRegression_4bc192cb341445680f1b', name='fitIntercept', doc='whether to fit an intercept term'): True,
#  Param(parent='LinearRegression_4bc192cb341445680f1b', name='labelCol', doc='label column name'): 'label',
#  Param(parent='LinearRegression_4bc192cb341445680f1b', name='loss', doc='The loss function to be optimized. Supported options: squaredError, huber. (Default squaredError)'): 'squaredError',
#  Param(parent='LinearRegression_4bc192cb341445680f1b', name='maxIter', doc='maximum number of iterations (>= 0)'): 10,
#  Param(parent='LinearRegression_4bc192cb341445680f1b', name='predictionCol', doc='prediction column name'): 'prediction',
#  Param(parent='LinearRegression_4bc192cb341445680f1b', name='regParam', doc='regularization parameter (>= 0)'): 0.01,
#  Param(parent='LinearRegression_4bc192cb341445680f1b', name='solver', doc='The solver algorithm for optimization. Supported options: auto, normal, l-bfgs. (Default auto)'): 'auto',
#  Param(parent='LinearRegression_4bc192cb341445680f1b', name='standardization', doc='whether to standardize the training features before fitting the model'): True,
#  Param(parent='LinearRegression_4bc192cb341445680f1b', name='tol', doc='the convergence tolerance for iterative algorithms (>= 0)'): 1e-06}
